# %%
"""
SHOPPING LIST / PSEUDO-CODE 


1.1) Visual and functional navigate strategy


empthy grid 

_  _  _
_  _  _  
_  _  _



TTT = "_  _  _\n_  _  _  \n_  _  _"
This is grapical more beautiful 


T1 = ["_", "_", "_"]
T2 = ["_", "_", "_"]
T3 = ["_", "_", "_"]
This is more practucal to replace 


2) Two players variables 

player = X 
computer = O 


3) Initational questions and prints  

- print ("Please choose on witch level you want to start, top, middle or bottom?") 
- #T1, T2 or T3
- code for input player []

- Print ("please choose on wich row you want to place tour cross, left, middle or right?") 
- #[0], [1], [2]
- Code for input player []


4) Computer logic 

Levels: 
T1[:]
T2[:]
T3[:]

Rows: 
R1 = T1[0]+T2[0]+T3[0]
R2 = T1[1]+T2[1]+T3[1]
R3 = T1[2]+T2[2]+T3[2]

Diagonals: 
D1 = T1[0]+T2[1]+T3[2]
D2 = T1[2]+T2[1]+T3[0]


No dager if: 
- If (Level or Rows or Diagonals).count("_") >= 1

Dager if: 
- If (Level or Rows or Diagonals).count("_") == 1

End of the game: 
- If (Level or Rows or Diagonals).count("_") == 0


5) Computer game strategy 


- If no danger:
    chose for increasing (Level or Rows or Diagonals).count("O")
    
- If danger:
    chose for last to replace element "_" in level or Rows or Diagonals. 


6) Closure

If (Level or Rows or Diagonals).count("X")== 3 
won_list = ["X!", "X!", "X!"]
print ("you have won!!")
print (won_list)
print (won_list)
print (won_list)

If (Level or Rows or Diagonals).count("O")== 3 
lost_list = ["O!", "O!", "O!"]
print ("You have lost...but well played!")
print (lost_list)
print (lost_list)
print (lost_list)

"""
# Out:
# '\nSHOPPING LIST / PSEUDO-CODE \n\n\n1.1) Visual and functional navigate strategy\n\n\nempthy grid \n\n_  _  _\n_  _  _  \n_  _  _\n\n\n\nTTT = "_  _  _\n_  _  _  \n_  _  _"\nThis is grapical more beautiful \n\n\nT1 = ["_", "_", "_"]\nT2 = ["_", "_", "_"]\nT3 = ["_", "_", "_"]\nThis is more practucal to replace \n\n\n2) Two players variables \n\nplayer = X \ncomputer = O \n\n\n3) Initational questions and prints  \n\n- print ("Please choose on witch level you want to start, top, middle or bottom?") \n- #T1, T2 or T3\n- code for input player []\n\n- Print ("please choose on wich row you want to place tour cross, left, middle or right?") \n- #[0], [1], [2]\n- Code for input player []\n\n\n4) Computer logic \n\nLevels: \nT1[:]\nT2[:]\nT3[:]\n\nRows: \nR1 = T1[0]+T2[0]+T3[0]\nR2 = T1[1]+T2[1]+T3[1]\nR3 = T1[2]+T2[2]+T3[2]\n\nDiagonals: \nD1 = T1[0]+T2[1]+T3[2]\nD2 = T1[2]+T2[1]+T3[0]\n\n\nNo dager if: \n- If (Level or Rows or Diagonals).count("_") >= 1\n\nDager if: \n- If (Level or Rows 
# ...

# %%
# 1) Visual and functional navigate strategy



level1 = ["_", "_", "_"]
level2 = ["_", "_", "_"]
level3 = ["_", "_", "_"]

#2) Two players variables 

print ("\nWelcome to the came of Tic Tac To!\n\nYou are'X'\nThe computer is'O'\n\nSee here our wonderfull raw python grid ;)\n")
print (level1)
print (level2)
print (level3)

print ("\nYou will start te game by first choosing a level.\n\nLevel 1 is :\n",l1,"\nLevel 2 is:\n", l2,"\nLevel 3 is:\n", l3) 

print ("\nThen proceed choosing the row 1, 2 or 3. \n\nrow 0: _ row 1: _ row2: _" )
# Out:
# Welcome to the came of Tic Tac To!
#
# You are'X'
# The computer is'O'
#
# See here our wonderfull raw python grid ;)
#
# ['_', '_', '_']
# ['_', '_', '_']
# ['_', '_', '_']
#
# You will start te game by first choosing a level.
#
# Level 1 is :
#  ['_', 'X', '_']
# Level 2 is:
#  ['_', '_', '_']
# Level 3 is:
#  ['_', '_', '_']
#
# Then proceed choosing the row 1, 2 or 3.
#
# row 0: _ row 1: _ row2: _

# %%
# 3) Initational questions and prints 

level=int(input("Please choose the level: 1, 2 or 3: "))
levellist = [1,2,3]
i = 0 
stop = 0 

if level in levellist:
    print("Good choice!")
    row =int(input("Please choose the row: 0, 1 or 2: "))
    rowlist = [0,1,2]
    if row in rowlist:
        print ("Again good choice!")
        stop = 1 
         
    else:
        print("Please Stick to the wonderfull python row options: 1, 2 or 3")
        # and then something to restart again to row choice 
    
else: 
    if stop == 0:
        print("Please Stick to the wonderfull python level options:n 0, 1 or 2")
        # and then something to restart again to level choice
# Out:
# Please choose the level: 1, 2 or 3: 1
# Good choice!
# Please choose the row: 0, 1 or 2: 1
# Again good choice!

# %%
if level == 1:
    if level1[row] == '_':
        level1[row]= "X"
        print (l1)
        print (l2)
        print (l3)    
    else: 
        print ("please choose again this spot is already taken")
        
elif level == 2: 
    if level2[row] == '_':
        level2[row]= "X"
        print (l1)
        print (l2)
        print (l3)
    else: 
        print ("please choose again this spot is already taken")
        
elif level == 3: 
    if level3[row] == '_':
        level3[row]= "X"
        print (l1)
        print (l2)
        print (l3)
    else: 
        print ("please choose again this spot is already taken")
# Out:
# ['_', 'X', '_']
# ['_', '_', '_']
# ['_', '_', '_']

# %%
#5) Computer game strategy 



#Rows: 
r1 = level1[0]+level2[0]+level3[0]
r2 = level1[1]+level2[1]+level3[1]
r3 = level1[2]+level2[2]+level3[2]
print (r1)

#Diagonals: 
d1 = l1[0]+l2[1]+l3[2]
d2 = l1[2]+l2[1]+l3[0]

# counter move 
level_1score = level1.count("X")
level_2score = level2.count("X")
level_3score = level3.count("X")

r1_score = r1.count("X")
r2_score = r2.count("X")
r3_score = r3.count("X")

d1_score = d1.count("X")
d1_score = d2.count("X")


score_list = [level1score] + [level_2score] +[level_3score] +[r1_score] + [r2_score ] + [ r3_score]  + [d1_score] + [d1_score]


print (score_list )

#print (score_list[score_list.index(max(score_list))]) # prints not out level1score only its value
# Out:
# ___
# [1, 0, 0, 0, 1, 0, 0, 0]

# %%
#6) Closure


# diagonal win check     
if (d1.count("X")) == 3:
    won_list = ["X!", "X!", "X!"]
    print ("you have won!!")
    print (won_list)
    print (won_list)
    print (won_list)

elif(d1.count("O")) == 3:
    lost_list = ["O!", "O!", "O!"]
    print ("You have lost...but well played!")
    print (won_list)
    print (won_list)
    print (won_list)
    
elif (d2.count("X")) == 3:
    won_list = ["X!", "X!", "X!"]
    print ("you have won!!")
    print (won_list)
    print (won_list)
    print (won_list)

elif(d2.count("O")) == 3:
    lost_list = ["O!", "O!", "O!"]
    print ("You have lost...but well played!")
    print (won_list)
    print (won_list)
    print (won_list)
    
# level win check        

elif (level1.count("X")) == 3:
    won_list = ["X!", "X!", "X!"]
    print ("you have won!!")
    print (won_list)
    print (won_list)
    print (won_list)

elif(level1.count("O")) == 3:
    lost_list = ["O!", "O!", "O!"]
    print ("You have lost...but well played!")
    print (won_list)
    print (won_list)
    print (won_list)
    
elif (level2.count("X")) == 3:
    won_list = ["X!", "X!", "X!"]
    print ("you have won!!")
    print (won_list)
    print (won_list)
    print (won_list)

elif(level2.count("O")) == 3:
    lost_list = ["O!", "O!", "O!"]
    print ("You have lost...but well played!")
    print (won_list)
    print (won_list)
    print (won_list)
    
elif (level3.count("X")) == 3:
    won_list = ["X!", "X!", "X!"]
    print ("you have won!!")
    print (won_list)
    print (won_list)
    print (won_list)

elif(level3.count("O")) == 3:
    lost_list = ["O!", "O!", "O!"]
    print ("You have lost...but well played!")
    print (won_list)
    print (won_list)
    print (won_list)
    
    
# row win check   


elif (r1.count("X")) == 3:
    won_list = ["X!", "X!", "X!"]
    print ("you have won!!")
    print (won_list)
    print (won_list)
    print (won_list)

elif(r1.count("O")) == 3:
    lost_list = ["O!", "O!", "O!"]
    print ("You have lost...but well played!")
    print (won_list)
    print (won_list)
    print (won_list)
    
elif (r2.count("X")) == 3:
    won_list = ["X!", "X!", "X!"]
    print ("you have won!!")
    print (won_list)
    print (won_list)
    print (won_list)

elif(r2.count("O")) == 3:
    lost_list = ["O!", "O!", "O!"]
    print ("You have lost...but well played!")
    print (won_list)
    print (won_list)
    print (won_list)
    
elif (r3.count("X")) == 3:
    won_list = ["X!", "X!", "X!"]
    print ("you have won!!")
    print (won_list)
    print (won_list)
    print (won_list)

elif(r3.count("O")) == 3:
    lost_list = ["O!", "O!", "O!"]
    print ("You have lost...but well played!")
    print (won_list)
    print (won_list)
    print (won_list)

# %%
l1 = 2
l2 = 4 
l3 = [l1] + [l2]
print (l3)
# Out:
# [2, 4]
